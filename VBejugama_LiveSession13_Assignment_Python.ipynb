# %%
my_list = [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6]
my_list[4]
# Out:
# 39.0

# %%
my_list.append(55.2)
my_list
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6, 55.2, 55.2]

# %%
my_list.remove(my_list[5])
my_list
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 47.4, 41.1, 45.8, 35.6, 55.2, 55.2]

# %%
for x in my_list: 
    if x>45: 
        print(x)
# Out:
# 45.4
# 47.4
# 45.8
# 55.2
# 55.2

# %%
import numpy
new_list = numpy.array(my_list)
new_list
# Out:
# array([ 45.4,  44.2,  36.8,  35.1,  39. ,  47.4,  41.1,  45.8,  35.6,
#         55.2,  55.2])

# %%
numpy.mean(new_list)
# Out:
# 43.709090909090911

# %%
numpy.std(new_list)
# Out:
# 6.7539153015733362

# %%
for x in new_list: 
    if x<45: 
        print(x)
# Out:
# 44.2
# 36.8
# 35.1
# 39.0
# 41.1
# 35.6

# %%
numpy.max(new_list)
# Out:
# 55.200000000000003

# %%
numpy.min(new_list)
# Out:
# 35.100000000000001

# %%
import pandas
iris = pandas.read_csv('/Users/vivek/Desktop/iris.csv')
iris.head(10)
# Out:
#    ﻿Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris.drop(['SepalLengthCm'],axis=1)
# Out:
#      ﻿Id  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0      1           3.5            1.4           0.2     Iris-setosa
# 1      2           3.0            1.4           0.2     Iris-setosa
# 2      3           3.2            1.3           0.2     Iris-setosa
# 3      4           3.1            1.5           0.2     Iris-setosa
# 4      5           3.6            1.4           0.2     Iris-setosa
# 5      6           3.9            1.7           0.4     Iris-setosa
# 6      7           3.4            1.4           0.3     Iris-setosa
# 7      8           3.4            1.5           0.2     Iris-setosa
# 8      9           2.9            1.4           0.2     Iris-setosa
# 9     10           3.1            1.5           0.1     Iris-setosa
# 10    11           3.7            1.5           0.2     Iris-setosa
# 11    12           3.4            1.6           0.2     Iris-setosa
# 12    13           3.0            1.4           0.1     Iris-setosa
# ...

# %%
iris_setosa = iris.loc[iris['Species']=='Iris-setosa']
iris_setosa
# Out:
#     ﻿Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0     1            5.1           3.5            1.4           0.2  Iris-setosa
# 1     2            4.9           3.0            1.4           0.2  Iris-setosa
# 2     3            4.7           3.2            1.3           0.2  Iris-setosa
# 3     4            4.6           3.1            1.5           0.2  Iris-setosa
# 4     5            5.0           3.6            1.4           0.2  Iris-setosa
# 5     6            5.4           3.9            1.7           0.4  Iris-setosa
# 6     7            4.6           3.4            1.4           0.3  Iris-setosa
# 7     8            5.0           3.4            1.5           0.2  Iris-setosa
# 8     9            4.4           2.9            1.4           0.2  Iris-setosa
# 9    10            4.9           3.1            1.5           0.1  Iris-setosa
# 10   11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
iris.describe()
# Out:
#               ﻿Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.groupby(by='Species').describe()
# Out:
#                        PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa     count      50.000000     50.000000      50.000000
#                 mean        1.464000      0.244000       5.006000
#                 std         0.173511      0.107210       0.352490
#                 min         1.000000      0.100000       4.300000
#                 25%         1.400000      0.200000       4.800000
#                 50%         1.500000      0.200000       5.000000
#                 75%         1.575000      0.300000       5.200000
#                 max         1.900000      0.600000       5.800000
# Iris-versicolor count      50.000000     50.000000      50.000000
#                 mean        4.260000      1.326000       5.936000
#                 std         0.469911      0.197753       0.516171
#                 min         3.000000      1.000000       4.900000
#                 25%         4.000000      1.200000       5.600000
# ...

# %%
# %matplotlib inline
iris.boxplot(by='Species')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B1A1351CC0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B1A246A0F0>]], dtype=object)

# %%
sns.pairplot(iris,hue='Species')
